# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Load data into data frame

# %%
MI = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_MI_ShortData.csv", index_col=0)
CSK = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_CSK_ShortData.csv", index_col=0)
CSK_Full = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_CSK_FullData.csv", index_col=0)
MI_Full = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_MI_FullData.csv", index_col=0)

# %%
MI_runs = MI.groupby('over').sum()
MI_runs.reset_index(inplace=True)
CSK_runs = CSK.groupby('over').sum()
CSK_runs.reset_index(inplace=True)
sns.color_palette("Paired")
#sns.set(rc={'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
#sns.set(style="whitegrid")
#fig, ax =plt.subplots(1,2,figsize=(12, 8))
f = plt.figure(figsize=(12, 8))
gs = f.add_gridspec(1, 2)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,18,2))
    g1.set_ylim(0,18)
    g1.axes.set_title("MI Innings",fontsize=20)
    g1.set_xlabel("Overs",fontsize=18)
    g1.set_ylabel("Runs",fontsize=18)    
    
with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[0, 1])
    g2 = sns.barplot(x='over', y='runs', data=CSK_runs);
    ax.set_facecolor("#fded13")
    ax.set_title('CSK Innings', color ="#fdb913") 
    g2.set_yticks(range(0,18,2))
    g2.set_ylim(0,18)
    g2.axes.set_title("CSK",fontsize=20)
    g2.set_xlabel("Overs",fontsize=18)
    g2.set_ylabel("Runs",fontsize=18)
    
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/BarPlot.jpg")

# %%
MI_runs = MI.groupby('over').sum()
MI_runs.reset_index(inplace=True)
CSK_runs = CSK.groupby('over').sum()
CSK_runs.reset_index(inplace=True)
sns.color_palette("Paired")
#sns.set(rc={'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
#sns.set(style="whitegrid")
#fig, ax =plt.subplots(1,2,figsize=(12, 8))
f = plt.figure(figsize=(12, 8))
gs = f.add_gridspec(1, 2)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.countplot(x="runs",data=MI)
    g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,60,10))
    g1.set_ylim(0,60)
    g1.axes.set_title("MI",fontsize=20)
    g1.set_xlabel("Runs",fontsize=18)
    g1.set_ylabel("Counts",fontsize=18)    
    
with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[0, 1])
    g2 = sns.countplot(x="runs",data=CSK)
    ax.set_facecolor("#fded13")
    ax.set_title('CSK', color ="#fdb913") 
    g2.set_yticks(range(0,60,10))
    g2.set_ylim(0,60)
    g2.axes.set_title("CSK",fontsize=20)
    g2.set_xlabel("Runs",fontsize=18)
    g2.set_ylabel("Counts",fontsize=18)
    #g2.set_xticklabels(['Dots', 'Singles','Twos', 'Threes','FOUR','5s','SIX'])
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/CountPlot.jpg")

# %%
RUNS = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_runs_line_graph.csv", index_col=0)
print(RUNS)
TOTAL = RUNS.drop(['Mirpo', 'Mirr',"CSKrpo","CSKrr"], axis=1)
RPO = RUNS.drop(['MITotalRuns', 'Mirr',"CSKTotalRuns","CSKrr"], axis=1)
RUNRATE = RUNS.drop(['MITotalRuns', 'Mirpo',"CSKTotalRuns","CSKrpo"], axis=1)
# Out:
#       Mirpo  MITotalRuns   Mirr  CSKrpo  CSKTotalRuns  CSKrr
# over
# 1        12           12  12.00       5             5   5.00
# 2         7           19   9.50       1             6   3.00
# 3         8           27   9.00       6            12   4.00
# 4        18           45  11.25       7            19   4.75
# 5         3           48   9.60       4            23   4.60
# 6         3           51   8.50      14            37   6.17
# 7         9           60   8.57       6            43   6.14
# 8         8           68   8.50       8            51   6.38
# 9        15           83   9.22       7            58   6.44
# 10        3           86   8.60      12            70   7.00
# 11        6           92   8.36      11            81   7.36
# 12       13          105   8.75       7            88   7.33
# 13       11          116   8.92      11            99   7.62
# 14        5          121   8.64       6           105   7.50
# ...

# %%
#sns.lineplot(x='over', y='value', hue='variable', data=pd.melt(RUNS, ['MITotalRuns','CSKTotalRuns']))
sns.color_palette("Paired")
#sns.set(rc={'axes.facecolor':'cornflowerblue', 'figure.facecolor':'cornflowerblue'})
#sns.set(style="whitegrid")
#fig, ax =plt.subplots(1,2,figsize=(12, 8))
f = plt.figure(figsize=(15, 12))
gs = f.add_gridspec(2, 2)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1=sns.lineplot(data=TOTAL)
    #g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,180,10))
    g1.set_ylim(0,180)
    g1.axes.set_title("Total Score",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Total",fontsize=18)   
    g1.set_xticks(range(1,21))
    g1.set_xlim(1,21)
    plt.legend(title='Score', loc='upper left', labels=['MI', 'CSK'])

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 1])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1=sns.lineplot(data=RPO)
    #g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,20,2))
    g1.set_ylim(0,20)
    g1.axes.set_title("Runs Per Over",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Runs per over",fontsize=18)   
    g1.set_xticks(range(1,21))
    g1.set_xlim(1,21)
    plt.legend(title='RPO', loc='upper right', labels=['MI', 'CSK']) 

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1,0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1=sns.lineplot(data=RUNRATE)
    #g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,16,2))
    g1.set_ylim(0,16)
    g1.axes.set_title("Run rate",fontsize=20)
    g1.set_xlabel("Over",fontsize=16)
    g1.set_ylabel("Run rate",fontsize=16)   
    g1.set_xticks(range(1,21))
    g1.set_xlim(1,21)
    plt.legend(title='RPO', loc='upper right', labels=['MI', 'CSK'])       
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/LinePlot.jpg")

# %%
CSK_BATTING = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_CSK_ShortData.csv", index_col=0)

CSK_BATTING = CSK_BATTING.drop(['text','preText','postText'], axis=1)
                            
CSK_BATTING['bowlerToBatsman'] = CSK_BATTING['shortText'].str.split(',').str[0]

CSK_BATTING['bowler'] = CSK_BATTING['bowlerToBatsman'].str.split('to').str[0]
CSK_BATTING['batsman'] = CSK_BATTING['bowlerToBatsman'].str.split('to').str[1]
CSK_BATTING = CSK_BATTING.drop(['shortText'], axis=1)

MI_BATTING = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_MI_ShortData.csv", index_col=0)

MI_BATTING = MI_BATTING.drop(['text','preText','postText'], axis=1)
                            
MI_BATTING['bowlerToBatsman'] = MI_BATTING['shortText'].str.split(',').str[0]

MI_BATTING['bowler'] = MI_BATTING['bowlerToBatsman'].str.split('to').str[0]
MI_BATTING['batsman'] = MI_BATTING['bowlerToBatsman'].str.split('to').str[1]
MI_BATTING = MI_BATTING.drop(['shortText'], axis=1)

#print(CSK_BATTING)

CSK_HeatMap = pd.pivot_table(CSK_BATTING, index=['bowler'], columns='batsman', values='runs', aggfunc=np.sum)
MI_HeatMap = pd.pivot_table(MI_BATTING, index=['bowler'], columns='batsman', values='runs', aggfunc=np.sum)
#https://matplotlib.org/tutorials/colors/colormaps.html

f = plt.figure(figsize=(12,12))
gs = f.add_gridspec(2, 1)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(MI_HeatMap, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("MI Batting Performance",fontsize=20)
    g1.set_xlabel("Batsman",fontsize=18)
    g1.set_ylabel("Bowler",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(CSK_HeatMap, annot=True, fmt="g", cmap='Wistia')
    g1.set_facecolor("#005ea0")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("CSK Batting Performance",fontsize=20)
    g1.set_xlabel("Batsman",fontsize=18)
    g1.set_ylabel("Bowler",fontsize=18)     
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)
    
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/HeatMap.jpg")

# %%
CSK_BOWLING = pd.read_csv("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/IPL_2020_csk_mi_1216492_CSK_Bowling_analysis.csv", index_col=0)
CSK_BOWLING = CSK_BOWLING.drop(['text','preText','postText'], axis=1)

CSK_BOWLING['bowlerToBatsman'] = CSK_BOWLING['shortText'].str.split(',').str[0]

CSK_BOWLING['bowler'] = CSK_BOWLING['bowlerToBatsman'].str.split('to').str[0]
CSK_BOWLING['batsman'] = CSK_BOWLING['bowlerToBatsman'].str.split('to').str[1]
CSK_BOWLING = CSK_BOWLING.drop(['shortText'], axis=1)
print(CSK_BOWLING)

#innings1['bowlerToBatsman'] = innings1['shortText'].str.split(',').str[0]
#result = pd.pivot_table(innings1, index=['Line',"Length"], columns='bowlerToBatsman', values='runs', aggfunc=np.sum)
CSK_line = pd.pivot_table(CSK_BOWLING, index=['Line'], columns='bowler', values='runs', aggfunc=np.sum)
CSK_length = pd.pivot_table(CSK_BOWLING, index=['Length'], columns='bowler', values='runs', aggfunc=np.sum)

CSK_ll_batsman = pd.pivot_table(CSK_BOWLING, index=['Line','Length'], columns='batsman', values='runs', aggfunc=np.sum)
CSK_ll_batsmanvsbowler = pd.pivot_table(CSK_BOWLING, index=['Line','Length'], columns='bowlerToBatsman', values='runs', aggfunc=np.sum)


#https://matplotlib.org/tutorials/colors/colormaps.html


f = plt.figure(figsize=(12,6))
gs = f.add_gridspec(1, 2)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(CSK_line, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("CSK Bowling Line vs Runs Conceded",fontsize=20)
    g1.set_xlabel("Bowler",fontsize=18)
    g1.set_ylabel("Line",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 1])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(CSK_length, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("CSK Bowling Length vs Runs Conceded",fontsize=20)
    g1.set_xlabel("Bowler",fontsize=18)
    g1.set_ylabel("Length",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)


f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/HeatMapCSK_Bowling1.jpg")
# Out:
#         ball  over  runs  isBoundary  isWide  isNoball            Line  \
# id
# 119060     6    20     2       False   False     False          Middle
# 119050     5    20     2       False   False     False  WideOutSideOff
# 119040     4    20     1       False   False     False             Off
# 119030     3    20     0       False   False     False             Off
# 119020     2    20     1       False   False     False      OutsideOff
# ...      ...   ...   ...         ...     ...       ...             ...
# 150        5     1     0       False   False     False      OutsideOff
# 140        4     1     4        True   False     False             Leg
# 130        3     1     2       False   False     False             Off
# 120        2     1     1       False   False     False          Middle
# 110        1     1     4        True   False     False      OutsideOff
#
#         Length        Shot    bowlerToBatsman   bowler   batsman
# id
# ...

# %%
f = plt.figure(figsize=(18, 15))
gs = f.add_gridspec(2,1)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(CSK_ll_batsman, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("MI Batsman scores vs Ball type & Runs Conceded",fontsize=20)
    g1.set_xlabel("MI Batsman",fontsize=18)
    g1.set_ylabel("CSK Line - Length",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=45)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)
    
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(CSK_ll_batsmanvsbowler, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("CSK Bowler to MI Batsman vs Ball type & Runs Conceded",fontsize=20)
    g1.set_xlabel("CSK Bowler to MI Batsman ",fontsize=18)
    g1.set_ylabel("CSK Line - Length",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=90)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)
    
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/HeatMapCSK_Bowling2.jpg")

# %%
MI_ll_batsman = pd.pivot_table(CSK_BOWLING, index=['Line','Length'], columns='Shot', values='runs', aggfunc=np.sum)
MI_ll_batsmanvsbowler = pd.pivot_table(CSK_BOWLING, index=['bowlerToBatsman'], columns='Shot', values='runs', aggfunc=np.sum)

f = plt.figure(figsize=(18, 16))
gs = f.add_gridspec(2,1)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(MI_ll_batsman, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("MI Batsman Shots vs Ball type",fontsize=20)
    g1.set_xlabel("MI Batsman Shots",fontsize=18)
    g1.set_ylabel("CSK Line - Length",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=90)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)
    
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
    g1 = sns.heatmap(MI_ll_batsmanvsbowler, annot=True, fmt="g", cmap='Blues')
    g1.set_facecolor("#fdb913")
    #g1.set_yticks(range(0,60,10))
    #g1.set_ylim(0,60)
    g1.axes.set_title("CSK Bowler to MI Batsman shots & Runs Conceded",fontsize=20)
    g1.set_xlabel("Shot",fontsize=18)
    g1.set_ylabel("CSK Bowler to MI Batsman",fontsize=18)        
    g1.set_xticklabels(g1.get_xticklabels(), rotation=90)
    g1.set_yticklabels(g1.get_yticklabels(), rotation=0)
    
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/HeatMapCSK_Bowling3.jpg")

# %%
#g = sns.FacetGrid(CSK_BATTING, col="batsman",  row="bowler")
#g.map_dataframe(sns.histplot, x="runs")
#sns.scatterplot(data=CSK_BATTING, x="over", y="runs", hue="batsman")
f = plt.figure(figsize=(14, 12))
gs = f.add_gridspec(2,1)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    g1= sns.scatterplot(data=MI_BATTING,x="over", y="runs", hue="runs", size="runs",  sizes=(20, 400), legend="full")
    g1.set_facecolor("#005ea0")
    g1.set_yticks(range(0,7,1))
    g1.set_ylim(0,7)
    g1.set_xticks(range(0,21,1))
    g1.set_xlim(0,21)    
    g1.axes.set_title("MI Innings",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Runs",fontsize=18)        
    g1.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)

with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1, 0])
    g1= sns.scatterplot(data=CSK_BATTING,x="over", y="runs", hue="runs", size="runs",  sizes=(20, 400), legend="full")
    g1.set_facecolor("#fdb913")
    g1.set_yticks(range(0,7,1))
    g1.set_ylim(0,7)
    g1.set_xticks(range(0,21,1))
    g1.set_xlim(0,21)    
    g1.axes.set_title("CSK Innings",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Runs",fontsize=18)        
    g1.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
        
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/ScatterPlots1.jpg")  
#print(CSK_BATTING)

# %%
#g = sns.FacetGrid(CSK_BATTING, col="batsman",  row="bowler")
#g.map_dataframe(sns.histplot, x="runs")
#sns.scatterplot(data=CSK_BATTING, x="over", y="runs", hue="batsman")
f = plt.figure(figsize=(14, 12))
gs = f.add_gridspec(2,1)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs); 
    g1= sns.scatterplot(data=MI_BATTING,x="over", y="batsman", hue="runs", size="runs",  sizes=(20, 400), legend="full")
    g1.set_facecolor("#005ea0")
    g1.set_yticks(range(-1,12,1))
    g1.set_ylim(-1,12)
    g1.set_xticks(range(0,21,1))
    g1.set_xlim(0,21)    
    g1.axes.set_title("MI Innings",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Batsman",fontsize=18)        
    g1.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)

    
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[1, 0])
    g1= sns.scatterplot(data=CSK_BATTING,x="over", y="batsman", hue="runs", size="runs",  sizes=(20, 600), legend="full")
    g1.set_facecolor("#fdb913")
    g1.set_yticks(range(-1,7,1))
    g1.set_ylim(-1,7)
    g1.set_xticks(range(0,21,1))
    g1.set_xlim(0,21)    
    g1.axes.set_title("CSK Innings",fontsize=20)
    g1.set_xlabel("Over",fontsize=18)
    g1.set_ylabel("Batsman",fontsize=18)        
    g1.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
    
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/ScatterPlots2.jpg")  
#print(CSK_BATTING)

# %%
f = plt.figure(figsize=(8,6))
gs = f.add_gridspec(1,2)
with sns.axes_style("darkgrid"):
    sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 3.5})
    ax = f.add_subplot(gs[0, 0])
    #g1 = sns.barplot(x='over', y='runs', data=MI_runs);
#    g1 = sns.countplot(x="runs",data=MI)
    g1 = sns.distplot(MI.runs)
    g1.set_facecolor("#6098bf")
  #  g1.set_yticks(range(0,60,10))
 #   g1.set_ylim(0,60)
    g1.set_xlim(0,7)
    g1.set_xticks(range(0,7,1))        
    g1.axes.set_title("MI",fontsize=20)
    g1.set_xlabel("Runs",fontsize=18)    
 #g1.set_ylabel("Counts",fontsize=18)    
    
with sns.axes_style("whitegrid"):
    ax = f.add_subplot(gs[0, 1])
    g2 = sns.distplot(CSK.runs)
    ax.set_facecolor("#fded13")
    ax.set_title('CSK', color ="#fdb913") 
    #g2.set_yticks(range(0,60,10))
    #g2.set_ylim(0,60)
    g2.set_xlim(0,7)
    g2.set_xticks(range(0,7,1))    
    g2.axes.set_title("CSK",fontsize=20)
    g2.set_xlabel("Runs",fontsize=18)
    #g2.set_ylabel("Counts",fontsize=18)
f.tight_layout(pad=3.0)
f.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/distribution.jpg")

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = " ".join(str(bowlertobat) for bowlertobat in CSK["postText"])
text = text.join(str(bowlertobat) for bowlertobat in CSK["preText"])

stopwords = set(STOPWORDS)
stopwords.update(["nan","see","us","br","till","felt", "hit","now","came", "match","back","one" "the","pick","end","sure","got","ball","still","overall","need","will","player","day","thing"])

#print(text)
# Create and generate a word cloud image:
wordcloud_csk = WordCloud(collocations=False,stopwords=stopwords,max_font_size=80, max_words=100, background_color="yellow").generate(text)


text = " ".join(str(bowlertobat) for bowlertobat in MI["postText"])
stopwords = set(STOPWORDS)
stopwords.update(["nan","see","us","br","till","overs","felt", "hit","now","came","blank","match","back","one" "the","pick","end","sure","got","ball","still","overall","need","will","player","day","thing"])

#print(text)
# Create and generate a word cloud image:
wordcloud = WordCloud(collocations=False,stopwords=stopwords,max_font_size=80, max_words=100, background_color="#6098bf").generate(text)


fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,15))
#fig.suptitle('Horizontally stacked subplots')
ax1.imshow(wordcloud_csk, interpolation='bilinear')
ax1.axis("off")
ax2.imshow(wordcloud, interpolation='bilinear')
ax2.axis("off")
fig.tight_layout(pad=3.0)
fig.savefig("/raj/UT-Masters/Fall2019/MachineLearning/Blogs/CSK_MI_2020/wordcloud.jpg")
